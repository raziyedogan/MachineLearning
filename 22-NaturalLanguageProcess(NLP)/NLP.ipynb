# %% [markdown]
# ## Natural Language Process (NLP)

# %% [markdown]
# NLP, makine ile insan arasındaki iletişimi sağlamak için, maching learning modellerini testlere uygulamak için oluşturulmuş bir yöntemdir.
#
# Konuşmalarımız mikrofon vs. gibi araçlar aracılığıyla bilgisayara aktarılıyor ve konuşmada ne söylendiğini anlamaya yarayan bazı machine learning teknikleri vardır. Bu machine learning tekniklerini bir insan diline uyguladığımızda NLP yapmış oluyoruz.
#
# NLP ile text classification yapabilirz. Örneğin bir lokantanın yemeklerine dair yorumlar bulunan bir site düşünelim. Bu sitedeki yorumları olumlu yorum ve olumsuz yorum şeklinde machine learning algoritmaları ile sınıflandırabilmemiz mümkündür. Ve sonrasında bizim yazdığımız bir yorumun olumlu bir yorum mu yoksa olumsuz bir yorum mu olduğunu bu maching learning modeli ile tespit edebiliriz.
#
# Bu dökümanda şunları anlatacağım:
#
#     - cleaning data: Mesela "**merHABA_" şeklinde bir string var. Bilgisayarın bu stringin "merhaba" kelimesi olduğunu anlayabilmesi için bu ifadeyi "merhaba" stringine çevirmeliyiz.
#
#     - bag of words: NLP'nin en temel feature çıkarma yöntemlerinden birisidir. Feature çıkartmak, bir texti machine learning uygulayabileceğimiz hale getirmektir.
#
#     - text classification: Mesela twitter'da kadınlar ve erkekler tarafından atılan twitler var. Bu twitleri machine learning algoritmasına vericez ve atılan twitin kadın tarafından mı erkek tarafından mı atıldığını sınıflandırmış olacağız. Yani atılan textin kim tarafından atıldığını sınıflandırmamızı sağlayacak.
#
# NLP kullanım alanları şu şekildedir:
#
#     predict genre of book, question-answer, summarization of book
#
# NLP için bazı kütüphaneler vardır:
#
#     nltk, spacy, standford nlp, open nlp

# %% [markdown]
# Kullanacağımız veri seti, twitter'da kadınlar ve erkekler tarafından yapılan açıklamaları içeriyor. Veri setinde bulunan description feature'sini kullanarak, açıklamayı bir kadının mı yoksa erkeğin mi yazdığına dair sınıflandırma yapacağız.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"gender_classifier.csv",encoding="latin1")

# %% [markdown]
# encoding="latin1" parametresi ile csv dosyasının içerisinde latin harflerinin olduğunu belirttim. Dosya isminin başındaki r harfi read'den gelmektedir.

# %%
data = pd.concat([data.gender, data.description],axis=1)
data
# Out:
#        gender                                        description
# 0        male                              i sing my own rhythm.
# 1        male  I'm the author of novels filled with family dr...
# 2        male                louis whining and squealing and all
# 3        male  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4      female  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
# ...       ...                                                ...
# 20045  female                                               (rp)
# 20046    male  Whatever you like, it's not a problem at all. ...
# 20047    male  #TeamBarcelona ..You look lost so you should f...
# 20048  female  Anti-statist; I homeschool my kids. Aspiring t...
# 20049  female                     Teamwork makes the dream work.
#
# [20050 rows x 2 columns]

# %% [markdown]
# concat metodu ile iki tane series ya da DataFrame birleştirilir. Yukarıda veri setinden kullanacağımız feature'leri sütun bazlı birleştirdim.
#
# Yukarıda çıktıda gördüğünüz üzere veri setinde, kadınların ve erkeklerin yazdıkları textler bulunmaktadır.
#
# Veri setinde bulunan anlamsız textleri ve nan ifadeleri çıkarmalıyız. Daha sonrada yazılan textlerin bir kadın mı erkek mi tarafından yazıldığını tespit edelim.

# %%
data.dropna(axis=0, inplace=True)  #axis=0 parametresi ile nan olan ifadelerin bulunduğu SATIR çıkarılır.

# %% [markdown]
# Sınıflandırma algoritmaları string ifade kullanamaz. Dolayısıyla sınıflarımı ifade eden gender sütunundaki verileri int veya categorical tipine dönüştürmeliyiz. male değerleri 0, female değerleri 1 olacak şekilde int tipine dönüştürelim:

# %%
data.gender = [1 if each=="female" else 0 for each in data.gender]

# %%
data.head()
# Out:
#    gender                                        description
# 0       0                              i sing my own rhythm.
# 1       0  I'm the author of novels filled with family dr...
# 2       0                louis whining and squealing and all
# 3       0  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4       1  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...

# %% [markdown]
# ## Regular Expression (RE)

# %% [markdown]
# Veri setinde bulunan :) gibi ifadeleri temizlemeliyiz. Veriyi temizlerken Regular Expression (RE) kavramından faydalanacağız. import re şeklinde kütüphanesi vardır.
#
# Regular Expression ile ingilizce alfabede büyük ve küçük şeklinde a'dan z'ye kadar olan harfleri bulucaz ve bu aralıkta olmayan harflerin (mesela :) gibi)  tespitini sağlayarak yerlerine boşluk koyucaz. Bu işlemi öncelikle veri setinden tek bir texten yapalım sonrasında tüm veri setine uygulayalım.

# %%
import re

first_description = data.description[4]

description = re.sub("[^a-zA-Z]", " ", first_description)

# %% [markdown]
# a-zA-Z ifadesi a'dan z'ye ve A'dan Z'ye olanları bul demektir. Bu ifadenin başına ^ koyduğumuzda a'dan z'ye ve A'dan Z'ye olanları bulma demektir. İkinci parametre ile a'dan z'ye ve A'dan Z'ye olmayanları boşluk ile değiştirdim. Bu işlem first_description değişkeninde tutulan texte uygulanır ve 3.parametre ile bunu belirttim.

# %% [markdown]
# Bilgisayar dilinde "the" ve "THE" kelimeleri farklıdır. Çünkü birisi küçük harfle diğeri büyük harfle yazılmıştır. Dolayısıyla text'teki harflerin hepsini küçük harfe çevirerek veriyi hazırlayalım.

# %%
description = description.lower()

# %% [markdown]
# ## Irrelavant Words (Stopwords)

# %% [markdown]
# Mesela " I go to the school and home" cümlesinde the ve and kelimeleri, texti kadın mı yazdı erkek mi yazdı ayrımı için bir anlam ifade etmez. Bu kelimeler insanlar tarafından sıklıkla kullanılabilir, cinsiyet ayrımı açısından bir anlamları yoktur. Dolayısıyla bu kelimeler Irrelavant Words'dür yani gereksiz kelimelerdir. Bunları data'dan çıkarmalıyız ve bunun için nltk kütüphanesine ihtiyaç vardır.

# %%
import nltk  # natureal language tool kit

nltk.download("stopwords")  #stopwords'ları yani gereksiz kelimeleri indirdim. stopwords'ler bilgisayarda corpus isimli bir klasöre indiriliyor.

from nltk.corpus import stopwords  # Sonra corpus klasöründen stopwords'leri import ediyorum.
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\raziy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Textin içerisindeki kelimeleri bir listede depolamamız lazım. Her bir kelime listenin bir değeri olmalı. Çünkü listedeki kelimeleri stopword'te bulunan kelimelerle karşılaştırırız ve eşleşen kelime varsa çıkarmalıyız.

# %%
#description = description.split()  #texti split() metodu ile default olarak boşluklardan ayırır.

# %% [markdown]
# split yerine tokenizer metodunu kullanabiliriz. Bu metod nltk kütüphanesinde yer alır.

# %%
nltk.download('punkt')

description = nltk.word_tokenize(description)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\raziy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
description
# Out:
# ['ricky',
#  'wilson',
#  'the',
#  'best',
#  'frontman',
#  'kaiser',
#  'chiefs',
#  'the',
#  'best',
#  'band',
#  'xxxx',
#  'thank',
#  'you',
#  'kaiser',
#  'chiefs',
#  'for',
#  'an',
#  'incredible',
#  'year',
#  'of',
#  'gigs',
#  'and',
#  'memories',
#  'to',
#  'cherish',
#  'always',
#  'xxxxxxx']

# %% [markdown]
# word_tokenize metodunun split'ten avantajı şudur:
#
# "shouldn't ve guzel" stringini split ile parçalarsak ["shouldn't", "ve", "guzel"] şeklinde bir çıktı alırız. Burada shouldn't ifadesi aslında should not dır. Bunu should ve not olarak ikiye ayırabilmek için word_tokenize metodunu kullanırız.

# %%
description = [word for word in description if not word in set(stopwords.words("english"))]

# %% [raw]
# Yukarıdaki satır ile the gibi text classification yapmada işe yaramayacak gereksiz kelimeleri çıkarmış olduk.

# %%
description
# Out:
# ['ricky',
#  'wilson',
#  'best',
#  'frontman',
#  'kaiser',
#  'chiefs',
#  'best',
#  'band',
#  'xxxx',
#  'thank',
#  'kaiser',
#  'chiefs',
#  'incredible',
#  'year',
#  'gigs',
#  'memories',
#  'cherish',
#  'always',
#  'xxxxxxx']

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# Erkek kullanıcıların açıklamaları şu şekilde olsun:
#
#     maça gitmek çok güzel
#
#     maç çok iyiydi
#
#     maçı kazandık
#
# Burada erkek olmasını ayırt edebileceğimiz ifade maç 'tır. Bilgisayar için yukarıdaki cümlelerde bulunan maça, maçı, maç 3 farklı kelimeyi ifade etmekte. Dolayısıyla bu kelimeleri MAÇ olarak modele öğretmemiz gerekmekte.
#
# Kelimenin köklerini bulmak için "Lemmatization" kullanırız.

# %%
nltk.download('wordnet')

import nltk as nlp

lemma = nlp.WordNetLemmatizer()

decription = [lemma.lemmatize(word) for word in description]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\raziy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Yukarıdaki kod bloğu ile text'te bulunan kelimelerin köklerini buldum.

# %%
description = " ".join(description)

# %% [markdown]
# Yukarıdaki kod bloğu ile description'da tutulan kelimeleri boşluk ile birleştirdim.

# %%
description
# Out:
# 'ricky wilson best frontman kaiser chiefs best band xxxx thank kaiser chiefs incredible year gigs memories cherish always xxxxxxx'

# %% [markdown]
# Yukarıda çıktıda görüldüğü üzere, gereksiz kelimeler texten çıkarıldı. Tüm kelimeler küçük harf oldu ve gereksiz kelimeler ortadan kalktı. Ve texte her bir kelimenin kökü bulunmakta.
#
# Şimdi veri setinin tamamına tüm bunları uygulayalım.

# %%
description_list = []

for description in data.description:
    description = re.sub("[^a-zA-Z]", " ", description)  
    #a-zA-Z ifadesi a'dan z'ye ve A'dan Z'ye olanları bul demektir. Bu ifadenin başına ^ koyduğumuzda a'dan z'ye ve A'dan 
    #Z'ye olanları bulma demektir. İkinci parametre ile a'dan z'ye ve A'dan Z'ye olmayanları boşluk ile değiştirdim.
    
    description = description.lower()  #Texteki tüm harfleri küçük harfe dönüştürdüm.
   
    description = nltk.word_tokenize(description)  #cümleyi kelimelere parçaladım.
    
    lemma = nlp.WordNetLemmatizer()
    decription = [lemma.lemmatize(word) for word in description]  #Tüm kelimelerin köklerini buldum.
    
    description = " ".join(description)
    #Gereksiz kelimeleri çıkarıp, kelimelerin köklerini bulduktan sonra tüm kelimeleri birleştirerek cümle elde ettim.
    
    description_list.append(description)

# %%
description_list
# Out:
# ['i sing my own rhythm',
#  'i m the author of novels filled with family drama and romance',
#  'louis whining and squealing and all',
#  'mobile guy ers shazam google kleiner perkins yahoo sprint pcs airtouch air force stanford gsb uva dad husband brother golfer',
#  'ricky wilson the best frontman kaiser chiefs the best band xxxx thank you kaiser chiefs for an incredible year of gigs and memories to cherish always xxxxxxx',
#  'you don t know me',
#  'a global marketplace for images videos and music sharing photos inspiration design tips videos for the creative community',
#  'the secret of getting ahead is getting started',
#  'pll fan crazy about mcd ramen is bae',
#  'renaissance art historian university of nottingham fuelled by haribo partial to coffee and with a soft spot for renaissance china national teaching fellow',
#  'clean food that tastes great while providing energy nutrients no guilt granola vegan paleo friendly options too cert organic gf kosher',
#  'highly extraordinary auctions',
#  'senior xi xii mmxiv',
#  'come join the fastest blog network online today http t co s mfpa vgk and http t co mpuuqtyf g we cover credit repair credit cards and bankruptcy',
#  'im just here for t p bo burnham and disney world',
#  'jmkm',
#  'over enthusiastic f fan model collector music fan and a film fanatic also an aspergian',
#  'artisan specializing in paper mache print making and fibre art art teacher and cat devotee find my page on fb https t co g bstg icv',
#  'he bled and died to take away my sins',
#  'union j xxxx',
#  'you had me from the start',
#  'bsc economics graduate coys',
#  'wife to my coach mom to my eight troops follower of christ',
#  'if you have any questions about islam and would like to answer them all you have to do is visit http t co alpmzgct x and chat with us',
#  'canadian space enthusiast future astronaut hopefully',
#  'my dms closed sc dear moonshine',
#  'rl writer lewd aspiring femboy who enjoys oneechans girlcock and such rts d and softcore d r nsfw accounts listed',
#  'breaking industry news for people who believe there s no such thing as too much tv you know who you are',
#  'award winning author of the paranormal romance thriller hath no fury technology writer http t co lmmiowenqq asmsg',
#  'self proclaimed princess and occasional pain in the ass',
#  'k smooty i drink alot could be worse i m scrolling through your girl s nudes while watching brady beat your team patsnation suprememeninist alwaysturnt',
#  'everything you need to find a job and keep it follow our tweet for new job posting',
#  'free ma bros ebk otr real all i kno is grind wea i come from',
#  'our nation s leading voice for childcare advocating for affordable high quality ece for working families undertakes research reports on child care data',
#  'penn state alum classof',
#  'mirage homage capri eternal hopeless romantic not really hopeles',
#  'lover of women dogs cats dogs movies comics tv video games books wrestling existentialism adult ent',
#  'a collective of genre specific blogs combining like voltron to provide you with the best coverage imaginable thefullbleed scifitalk geeklegacy the thmatrix',
#  'militante y obrero de los sue os revolucionarios desde toda la vida chavista de coraz n comandante vives x pre',
#  'love animals fetchfind is the new way to find jobs and network for the pet industry mascot heyfetchy fetchylovesyou',
#  'baby i m perfect for you niallofficial',
#  'kennedy j abulala ni mwalimu anayeienzi kazi yake mwalimu wa kiswahili',
#  'krothedj gmail com instagram djkro',
#  'slightly ginger with blue eyes park run',
#  'just living life at the top of the food chain',
#  'nss ipgkk',
#  'home office business are sweet business i can do it you can',
#  'goodmorning mentions anyone retweeet must follow back fav for a follow',
#  'pc xbox playstation esports music edm stocks sex',
#  'warholian obsessor creating within an orwellian nightmare allsceneeye larecord',
#  'the blades instagram scottryan',
#  'this is control jpn version zoe o jbot rayark implosion',
#  'you can have what you want in life advertise your service here for free and get rid of money worries',
#  'just a curious guy',
#  'discover how to heal your illness and pains',
#  'team di reporter e giornalisti lavoriamo con video e web la nostra giornata tra cronaca attualit politica e sport info smlive it',
#  'i like to sleep',
#  'ask no questions and you ll get no lies spoopytaylor',
#  'for any photography bookings or enquiries dm call me on or email me at abphotography gmail com insta a b photography teamchrist',
#  'born in czech republic live in ireland wan na be in germany ouat oitnb',
#  'you are to me all that an angel could be',
#  'following the money opening governance fighting corruption globalintegrity opengovhub tweets my own',
#  'retired bad girl queen',
#  'walk by faith not by sight',
#  'h ncisla bones castle arrow chicago fire chicago pd poi elementary tbbt agents of shield grey s anatomy the last ship callen mcroll ajax lfc bar a rafa nadal',
#  'apollo bot pulling from both aj and dd randomly posts every hour spoilers abound under construction progress complete',
#  'south beach th street miami beach fl sunny isles beach collins ave c sunny isles beach fl',
#  '',
#  'like the snow beautiful but cold i m a legal drug dealer original extraordinary and psychic if you want to know me better talk to me',
#  'official twitter account of the wichita falls wildcats nahlhockey south division est restoretheroar',
#  'wife of tidy boy amadeus director of the ideal place and proud mother of max mozart',
#  'delivering you up to date news from the entertainment world',
#  'a lie gets halfway around the world before the truth has a chance to get its pants on',
#  'lover of the truth seeker of knowledge',
#  'why chase trends when you can make a statement hoodlyfe https t co abfak idjb',
#  'calm and collected followbackandsee',
#  'artist re evaluating life radiation oncology student want make a ve difference comedian rule breaker forcelectures live drawz http t co nsf zd hfy',
#  'tcg is a staffing firm that places design interactive and marketing professionals in freelance and full time jobs see all our jobs here',
#  'hi my name is angela but most of my friends call me angie i have a very boring life consisting of college work so i have nothing to post for a bio',
#  'sports media opinion established contact us jmcintyre usatoday com',
#  'i repair all makes and models of phones tablets mp players more i ve been professionally repairing electronic equipment since',
#  'sportswriter cigar lover dreamer pro writer for sportsblog ustadium ambassador and suffering yankees nets jets fan fau',
#  'charity volunteer',
#  'hip hop usb albums breakstix usb break beats http t co iaof r hv',
#  '',
#  'the card that get you everywhere anything anyhow please use the credit card wisely please get the tips of using credit card from my site',
#  'boring boring chelsea',
#  'all the dallas tx news you need in one spot thanks for following and please send along any suggestions you may have',
#  'maker conceptor creative developer xbac a bd conception geek dev agile neutralite opensource privacy copyright',
#  'calm and cool',
#  'a retro modernist suffering from unsightly visibility',
#  'multiple sclerosis lives here in brant county and together with our community partners we want to do all we can to help those living with this disease',
#  'doctorate in physics time olympic swimming gold medalist and professional liar',
#  'i only trust people that like big butts they can not lie',
#  'dont take my tweets serious and if you do shrugs shit happens look at my link and pin i have no reason to be on here now',
#  'come to agrown s agtech investor conference and join the convo on cea in the us feat jayfamiglietti genegiacomelli meiny prins actonclimate agcon',
#  'community outreach medicaid managed care board member united way chicago m a gerontology advocate for underserved communities isu alumni',
#  'ventas digitales ibm espa a todas mis opiniones son personales y las hay de todos los colores tambi n puedes contactarme en http t co u r x hr',
#  'freeza ripnazerah',
#  'f p f',
#  'weekly hip hop podcast new show every wednesday rooted in hip hop limited to nothing marketing excusemyadlib com',
#  'you re a catalyst to your happiness',
#  'idiot from baltimore who thinks he is funny',
#  'computer engineer khalifa university',
#  'studying at dillard university dr williams',
#  'leonel dominic',
#  'gb for years not usually a twitter twat following the chat regarding the fight demise of our once noble trade those in the know have lot to answer for',
#  'how to quit paying for expensive medical visits and fake fixes and eliminate his frustrating nagging and constantly repeating low back pain',
#  'born london grew up basildon lived cornwall most of that at sea makes no sense but that s fine',
#  'i just signed myself',
#  'journalist and producer with camanpour on cnni always open to a spicy taco views are my own rt endorsement duh',
#  'curating the best media feeds in palo alto a city in http t co dtwyrmizau a community service media network supporting the social good',
#  'en webradio music non stop from fantastic sci fi movies and tv shows from the early s to the present day fr radio sf et fantastique',
#  'your brain is that bodily organ which starts working the moment you awake and does not stop until you get into the class',
#  'no ja online gist entertainment news musics videos events celebrity focus interviews life style fashion videodirector mc expy',
#  'learn all new aussiebodysecrets',
#  'hollow heart',
#  'it hurts to let go sometimes it seems the harder you try to hold on to something or someone the more it wants to get away',
#  'like my tweets you can support my work by shopping on amazon via this link thank you for being a good person http t co ebogxhl r',
#  '',
#  'magnificent fujoshi scum',
#  'just a girl in love with god pole vaulting lifting reading and horseback riding are my passions country loving small town girl',
#  'some days i want world peace other days i want to burn the world down',
#  'everything i do need a news crew s presence',
#  'ent o est bem sporting clube de portugal',
#  'living loving the electronic dance music scene edm is our life follow us come say hi when you see the honeys the next edm festival you go',
#  'real estate global network the social network for real estate professionals',
#  'the island s official magical creature omg you can t just ask me why i m white avi header are me barnqueenacc r wellbeing ambassador',
#  'helping build a supercomputer because no one s making giant robots anyhow it s keeping busy until the send me to mars all tweets cc by http t co mtenmjd xx',
#  'train like you ve been picked for the hunger games',
#  'looking for a miracle you re fucking with the right one jess',
#  'home to schools of management bcomm programs mba programs msc innovative research centres all in the core of downtown toronto',
#  'year old married broad makeup artist stylist raising to beautiful girls to be strong beautiful women wife to a roughneck',
#  'the capital area food bank of texas is a nonprofit dedicated to nourishing hungry people and leading the community in ending hunger',
#  'creolemixed borninneworleans raisedintexas love god family friends education sleep text food movies music clothes makeup nature animals colors',
#  'pronounced val er http t co ezqpnsavnr dedicated livestreamer avid pepsi drinker greenmangaming partner proud member of the keefcult big wwe fan',
#  'hi my name is louanne i am great fan of justin bieber and i love you o',
#  'national security foreign policy editor cqnow pulitzer crisis center grantee former qatar expat medill grad retweets not endorsement',
#  'the latest new york rangers buzz',
#  'writer stoop hen into books punk and gin writes for cash at iqmediacorp working on nsfwstory foul mouth cyclist',
#  'if you re ever feeling weak just remember that i am strong and i am out there copilot darklylacquered trine coldconstructed rockdoves',
#  'the ultimate gourmet coffee store from espresso to whole bean coffee https t co u ppcrfrsq https t co snem ypeak',
#  'christian conservative baptist believer in constitution and founders own book business republican theologian historian',
#  'a collective of genre specific blogs combining like voltron to provide you with the best coverage imaginable thefullbleed scifitalk geeklegacy the thmatrix',
#  'have you got an adsense publisher account with this tool you can multiply your income as many times as you wish http t co gbictcktae',
#  'marinasdiamonds dailymatd we d already performed at v it s not alternative but it s not pop a lie',
#  '',
#  'tweeting things around pennsylvania i like and enjoy if interested in twitter marketing save today info nicolamarketing com',
#  'health nut retired teacher family man programmer developer technician pc cnc entrepreneur more god',
#  'you dont need to much about me cuz my action and characters will tell you who i am i am kingabdul',
#  'a division of on the ground news canada join your friends reading the latest gaming news on the ground',
#  'weekly nationally syndicated alternative radio newsmagazine with timely in depth progressive analysis not found in corporate media',
#  'why oh why oh why oh why oh why',
#  'the latest business advice and strategy from businessinsider',
#  'sick from the lips caramel wan na try it bafhouse teamprettypothead the perfect balance between badass and feminie di hempress empress',
#  'american made jeans built to be the leader in fit quality and style bringing the best parts of the fashion world to the western world',
#  'experience conflict commentary realism',
#  'hampton university',
#  'curating the best media feeds in cleveland a city in http t co l qvbrl a community service media network supporting civic causes and local arts',
#  'owner of jlj holdings llc real estate consultant owner of feel real estate service llc',
#  'finna be lit vancini',
#  'a solar powered sigh machine mostly footy talk',
#  'insta brownlouise',
#  'the card that get you everywhere anything anyhow please use the credit card wisely please get the tips of using credit card from my site',
#  'i m is a czech adult model and pornographic actress with inch natural breasts currently livin in london you can follow me and retweet me every day luv u',
#  'official city of coralville ia government twitter account follows rts endorsement comment info http t co gayp dffh',
#  'tammy r sc kredo x',
#  'bb s official twitter account caution barracuda patrolled waters followed by dloesch newsbusters governorperry fredthompson twitchyteam chuckwoolery',
#  'i m that evil conservative obama warned you about pro palin conservative pro life',
#  'i love jesus miranda lambert jle leopard print a little jack in my coke',
#  'we ve helped over people with debt tax and estate problems since we re as friendly as we seem on tv with our experience why go anywhere else',
#  'se un uomo non disposto a correre qualche rischio per le sue idee o le sue idee non valgono nulla o non vale nulla lui cit',
#  'striving for the islamic way of life the right deen in the sight of allah is only islam',
#  'full time cruising sailor writer abiding interest in books boats the sea and classic guitar',
#  'we tweet las vegas deals and share sin city s secrets along the way follow if you love vegas stripdeals gmail com',
#  'i don t want to be the british justin bieber i want to be the first conor maynard conor maynard met joe caspar called me babe',
#  'bambam a jyp nation september th park jaehyung called me broski',
#  'unknown',
#  'creator of on location education the nation s premier educational consulting service for young performers passion for education film theater crime dramas',
#  'onedirection directionerforever criminalminds harmonizer abrahamers afonica soy liam girl ig selly',
#  'we are the no world fastest growing seo small big job services for buyer seller to meet',
#  'current mood jet black heart i only go in one direction',
#  'daily tips and motivation for a healthy lifestyle diet nutrition eat right feel great be healthy',
#  'soco i randolph college l it s so hard to leave until you leave then it s the easiest goddamn thing in the world',
#  'en construcci n literatura lisensiada en estudios ingleses zurda mel mana peligro constante i solemnly swear that i m up to no good',
#  'owner of a cocker spaniel amateur baker of all things nice jam and marmalade maker mane chance horse sanctuary owner of a tr',
#  'geek gamer writer beard advocate don of the twittermafia',
#  'the jewish federation of greater philadelphia s mission is to mobilize financial and volunteer resources to address the community s critical priorities',
#  'terrani s dad she comes before everybody rastaman',
#  'find the latest jobs careers in uk follow our tweet',
#  'curating the best media feeds in sydney a city in http t co anaoqyuffs a community service media network supporting civic causes and local arts',
#  'vcu s on campus technology store proudly serving vcu students faculty and staff by providing technology products and services under the same roof',
#  'lover of all outdoor things subtly charming geek massage therapist mindful',
#  'talent board thecandes vp talentculture tchat show co founder co host tas hcs certified hr recruiting writer wannabe drummer grateful father',
#  'sure fine whatever',
#  'eo soo seon my smol',
#  'author of the novel a trip to aret',
#  'do you like i do me be about your buisness',
#  'writer of gay romance gay erotica and lgbt literary fiction choose carefully on amz http t co hr i ddu',
#  'mu pt',
#  'love is like a car accident they hit you and you fall and then you survive or don t survive we love each other cuz our weakness are the same',
#  'when the going gets tough the tough get going',
#  'se asian goat kid march she her currently still much jojo much bike saso team abuyagi',
#  'formerly leading edelman indonesia public affairs across se asia joining http t co gscdas an september st as senior vice president brazil lead',
#  'featured nfl columnist and gameday writer for bleacher report former army engineer lover of all things sarcasm and satire pfwa member',
#  'no matter what ups and downs happy or sad moments i ll always be here for gaga saw her she followed and noticed me many times',
#  'phoenix city and press',
#  'swazijive united wife kids in that order mufc masters degree in banterology not arrogant just better red devil ig iam makhubu',
#  'just lay back and enjoy life austin cole',
#  'i m love singing dancing food painting tom bertram lol i m awesome like that i am a viner go follow me varsha nair',
#  'primo deus god first music',
#  'curating the best media feeds in regina a city in http t co lpvxd mnax a community service media network supporting civic causes and local arts',
#  'naturally and artificially flavoured',
#  'the way baby monitor is very useful both for parents and for babies the parents can hear the sound of the baby it is important to choose a reliable one',
#  'follow for fut ios android bargains giveaways use pic legitjaz if you win a giveaway or bargain dm me if you want to sponsor any giveaways',
#  'vegan married batman the simpsons metal harsh noise xtapolapometal',
#  'carla maltos iixii',
#  'classics professor at haverford canophile yankees fan occasional gardener and onetime sailor',
#  'hi my name is kevin i am a dota player from germany follow me to know when i start streaming',
#  'world largest affordable seo market place for seller and buyer freelancer small big jobs online service to meet',
#  'partner in pr firm expertise interests in crisis communications management public policy economic development media tech aviation and healthcare',
#  'hey norman how did andy s dick feel click on link to find answer',
#  'instagram oliviamockford',
#  'time is a ghost',
#  'sagi babe',
#  'the walking dead comics tim burton turtles owls harry potter star wars hacky sack m music life r i p mitch lucker rise records street team',
#  'indianapolis city and press',
#  'brooke writer artist video game fanboy they them snapchat thequeenbrookie',
#  'live content curated by top urban planning influencers',
#  'made of birds enix weird developing fallow she her',
#  'all i do is complain and get drunk',
#  'do you want to earn money from bitcoin let the insider tell you',
#  'muhammad fitri adam',
#  'the latest toronto maple leafs buzz',
#  'making giant novelty cheques since',
#  'singer arranger music producer',
#  'aba instructor grad student couponer deal hunter freebie snatcher blogger iphoneography lover and social media butterfly',
#  'doesn t matter how slow you go as long as you don t stop westfield insurance pinnacle sports gobrowns gobucks believeland',
#  'businessman entrepreneur internet marketer earn up to in a single day with this remarkable new idea free video for all https t co dl kzcvxue',
#  'wapo national reporter seek truth give voice to the voiceless shine light in the darkness other considerations are of minor importance',
#  'niall horan como respuesta a todo larry como ox geno liam mi baby zquad zayn girl',
#  'ed taylor',
#  'i will go into survival mode if tickled',
#  'i m done',
#  'we love manchester united we have beards we are the bearded reds we discuss everything united check the podcast',
#  'newly married kids everton rule',
#  'get me a normani video',
#  'curating the best media feeds in belmont a city in http t co hw alqpwg a community service media network supporting civic causes and local arts',
#  'updates on games and other things technology related mostly',
#  'commercial director at zignia live member of the board at water happiness',
#  'fuck it is dummy',
#  'abbey gilbert raemorrismusic we are all work in progress',
#  'lyrically driven ska punk reggae from the east coast check out our new release sublime with no one on itunes proudly sponsored by prsguitars',
#  'we call ourselves a neighborhood haunt that focuses on great ambiance delicious food classic libations',
#  'i am',
#  'nerd wrangler at riot games',
#  'i like to call myself a writer melanin curls pro woman pro black reader blogger',
#  'mommy to ka leighceriyah',
#  'we came from different family biologicaly but our heart beats as one kathniel',
#  'sportalk sports meet social media this account covers the philadelphia eagles join sportalk today and get the app http t co qyommzx df eagles nfl',
#  'good vibes only',
#  'just open your eyes something beautiful is happening al',
#  'polinema tek informatika basket polinema i like basket how about you http t co lgxn bgetc',
#  'how to quit paying for expensive medical visits and fake fixes and eliminate his frustrating nagging and constantly repeating low back pain',
#  'love to read favourite book series is fifty shades of grey fan of stephen moyer and jamie dornan love watching true blood big rookie blue and mcswarek fan',
#  'brand development manager and husband of new york times bestselling independent author nicoleeauthor',
#  'bueno hola me llamo kevin tengo a os viivo en no se donde me gusta cantarl l d u de soii tiimiido add facebook amo a mi novi',
#  'i draw filthy stuff',
#  'only big tits pictures from my site',
#  'swiftie forever always i m i the script cats music traveling tennis basketball ice skating i can play the guitar piano ukulele a bit',
#  'incurable tv evangelist',
#  'if relationship can t survive the long term why on earth would it be worth my time and energy for the short term deals bargains forsale onsale discount',
#  'learn all things about revolution of bitcoin their opportunities a very simple way to earn money using bitcoin',
#  'wasted',
#  'a collective of genre specific blogs combining like voltron to provide you with the best coverage imaginable thefullbleed scifitalk geeklegacy the thmatrix',
#  'crazy toys in the attic i am crazy truly gone fishing they must have taken my marbles away',
#  'family less is more influence healthcare compliance triathlete askhcsi',
#  '',
#  'longwood basketball r i p dad portia tony',
#  'i am a socio legal technologist inventor of conset receipt focused on personal data control',
#  'free omb only fear allah real demons loose screws',
#  'semper paratus',
#  'waiting for gandalf to come to my house and invite me on an adventure from which i will not expect to return',
#  'te quiero m s que ayer pero menos que ma ana',
#  'greek god of stats for espn s mikeandmike christ follower moneyball disciple punk rock enthusiast lebanese food connoisseur',
#  'blogger intermediario assicurativo esperto di pallacanestro livornese tifoso del milan e della libertas livorno webdesigner e webmaster blogger politico',
#  'hey angel',
#  'steam little arab insta little arab kik ahmadabed',
#  'who cares what people think',
#  'i have arms and legs',
#  'follow ysk baltimore for the latest news in the baltimore maryland area http t co doixknlfdp',
#  'freelance job from seo design writing social media and many more a place for buyer seller to meet',
#  'no ja online gist entertainment news musics videos events celebrity focus interviews life style fashion videodirector mc expy',
#  'a division of on the ground news canada join your friends reading the latest gaming news on the ground',
#  'please block me',
#  'just a small town girl convinced that she was born on the wrong side of the mason dixon started',
#  'spooky bisexual teenager intersectional feminist was feminist kid',
#  'offering affordable travel at the best locations',
#  'the official twitter feed of eckerd athletics follow us for updates galore member of d ssc and ncaadii',
#  'wael abdelkarim',
#  'hjv sc skysky',
#  'u r m a not affiliated with the nfl or san diego chargers',
#  'attorney speaker and legal analyst http t co gpbrj wa n and http t co ts cihefn',
#  'second floor at tootsies gettin shoulder rubs',
#  'communicator coffee enthusiast infuriatingly humble music nerd subtly charming internet guru alcohol fanatic',
#  'just a girl wanting big things out of life',
#  'any questions',
#  'leyton orient blogger and author i promised to tattoo my face for this stupid club and what thanks did i get lofc',
#  'the card that get you everywhere anything anyhow please use the credit card wisely please get the tips of using credit card from my site',
#  'nois noa precisa de nenhum papel da prefeitura',
#  'veninataviveci',
#  'life is not about waiting for the storms to pass it s about learning how to sing and dance in the rain',
#  'a real estate enthusiast working at royal lepage atlantic looking to sell or purchase i am a tweet away',
#  'my thrillers will entertain you while scaring you into changing all your passwords author of social engineer and invasion of privacy http t co l pvxnrord',
#  'music library for knarkse there s gon na be a lot of repeats and garbage',
#  'commercial director at zignia live member of the board at water happiness',
#  'published producer songwriter just making wavy music from the odd plug witthat for beats inquires email pianoboytod gmail com',
#  'anti coming soon',
#  'kind of tall with hair wears t shirts sometimes building a mystery',
#  'metal hammer deputy editor whatculture wwe goon neeerrrrrrddddd',
#  'just read latest and hot news from all over the world at newsviewsworld',
#  'aunty nuts i have a blog i love tea i love candles space doodles http t co awlemdc ut',
#  'learn how to create your own bestseller on amazon audio sessions will tell you all you need to know',
#  'i m not a frog k',
#  'producer kennvad uk http t co h dtj kl sevenstudio italy booking info douglas entertainment co uk',
#  'years supporting hereford united in the sw with a not too well body hereford fc onwards upwards united we are',
#  'natural californian',
#  'actor writer filmmaker father husband gamer fanboy and i got what it takes to rock the mics right yeah',
#  'that s what i meant all along really',
#  'bitcoin enthusiast',
#  'formerly known as the subway serenade now known as the astral technician i m currently developing global biofeedback laser tag',
#  'paper chasin paper runnin paper gunnin paper gettin paper havin paper catchin dont forget that paper grab it',
#  'get updates of whatever is happening on diymagazine in an easy feed',
#  'i like boybands and reading books bit obsessed with emmerdale robron instagram rachelh',
#  'trust no one ripspann s up talk about rihanna kingjames you just might get yo head buss dreambig amosc phineasandferg',
#  'curating the best media feeds in redwood city a city in http t co lemjjzzwxs a community service media network for the social good',
#  'get what i want cause i ask for it not because i m really that deserving of it',
#  'a tradition of excellence for years',
#  'co host of xl primetime on xl',
#  'cool kind of confused',
#  'the rose affair is dedicated to helping poor families who could not afford medicals for their kids',
#  'content social media marketing for business brands public figures non profits that value their online reputation personal voice kerijaehnig socialmedia',
#  'freejalen llh',
#  'businessinsider s roundup of experts partners and news outlets from across the media landscape',
#  'i m allergic to cheatin and i hate failure and i am in love with achievement',
#  'take your business to the next level with am amazon bestseller increase your credibility and your income',
#  'damn the man socially awkward extrovert ig sianchristinak',
#  'hail to the moon tell your father your friends you cant lock the door cause shes already in ig helenkdavishkd life saver manager of strainaddicts',
#  'lover of life and of all things artistic creative or beautiful especially people mama to hollymorwenna finntalisker',
#  'traveler writer b b host beer drinker kitty petter independent travel off the beaten track and volunteering http t co gqnujjc al',
#  'artist writer devourer of potatoes art atheism feminism science improv politics games health fam nerdy stuff writing weather minutiae',
#  'living with depression trying to end stigma re poor mentalhealth whitney fan nice watches amateur photographer gay graduate aspiring journalist',
#  'i started as web researcher got passion in seo now working as seo analyst sem ppc inbound marketing smo lead generation i tweet seo general things',
#  'writer lyricist coffee enthusiast world class barista semi pro mixologist mbonisigusto gmail com',
#  'an online writing school with top instructors and great classes at affordable prices',
#  'alex ac clifford clarkston varsity bowling srt also a pool shark ib class of wichita maybe',
#  'only fools fall for you azul no verde ddl d zayn troye',
#  'have a question follow us and let us help you product support http t co egtge se business support http t co mm axaey',
#  'xo',
#  'apple freak girl and love games',
#  'life s too short to drive a boring car slowg https t co kt l t amr',
#  'fight the good fight of faith lay hold on eternal life whereunto thou art also called timothy jesus christ is the only way bachelor degree bible studies',
#  'internet marketing adsense im money youtube tips on making money online with adsense youtube http t co gbictcktae',
#  'choose to be happy you don t own all the problems in the world emison hollstein xena gabrielle',
#  'hi',
#  'uknetguide find a flight or book one of hotels around the world great deals and offers',
#  'food fanatic incurable troublemaker',
#  'skateboarding money bml',
#  'ghareebah snapchat saynabeyy prayfortheummah',
#  'i launch books and optimize amazon book pages increase your ranking keep it there',
#  'the twitter page of the renfrew county district school board',
#  'book promotions amazon bestseller program social media programs',
#  'web marketing expert specializing in book promotions',
#  'pike podcasting est promo music sports lifestyle entertainment politics comics fantasy movies sex debauchery what else',
#  'welcome to east public school ps e our school motto is where the learning starts enzo guarnaccia principal',
#  'connecting people and churches of the fellowship of grace brethren churches',
#  'don t quit suffer now and live the rest of your life as a champion muhammed ali box for chadd abc loyalty is everything derby season ticket holder',
#  'a project of the foundation for defense of democracies followfdd rts favorites following endorsement',
#  'don t think for a second that i actually care what you have to say',
#  'concerns animal welfare h o quality species risk charter rights plight of wrongly convicted pls visit support http t co ilyj mw',
#  'un fan de football fan du club africain fan du wwe fan du counter strike',
#  'osceola county rep recording artist pen pimper peace seeker positive vibe pusher ig homelessmillionaire for all business email allenyorkmusic gmail com',
#  'follow me on instagram amandacleghorn taylor swift dancer sytycdc top female',
#  'we deliver apple mac news to nearly followers on twitter follow us on g at http t co iwja f tg',
#  'host of the morning grind mornings am minneapolis podcast me soundcloud https t co xew bekf also there is an am app i lean leftwards',
#  'don t make a permanent decision for your temporary emotion',
#  'different angle https t co ndfm burus',
#  'the rose affair is dedicated to helping poor families who could not afford medicals for their kids',
#  'mom currently divorcing comic crohn s advocate dr phil social media contributor member of inner circle',
#  'like to do fun activities utsa spursnation',
#  'book promoter',
#  'book promotions amazon bestseller campaigns social media systems and more',
#  'a catalog that will change your life with inspirational motivational metaphysical books programs and products and much much more',
#  'i am a retired sea captain i was born in england and eventually emigrated to the united states where i continue to write for my own enjoyment and comfort',
#  'student at university of cambridge',
#  'god first jiggaworld november st clothing line coming soon',
#  'older than you think rajna hussain',
#  'instagram josealejandro skype j',
#  'we provide book promotions amazon bestseller campaigns and social media platforms',
#  'she is clothed with strength dignity and laughs without fear of the future proberbs bhs senior k free my brother codey',
#  'leading global engineering firm providing professional engineering and consulting services to leaders in the aerospace automotive energy and nuclear sectors',
#  'i enjoy weather',
#  'vendedor de sue os tambien vendo libros',
#  'instagram briannaamurray',
#  'it professional rock roll accordionist bomber forever',
#  'get updates of whatever is happening on diymagazine in an easy feed',
#  'a collective of genre specific blogs combining like voltron to provide you with the best coverage imaginable thefullbleed scifitalk geeklegacy the thmatrix',
#  'multi award winning bridal hair make up stylist event florist hollywood lash technician',
#  'the latest from the bostonglobe metro department tweets by andyrosen globefinucane and jrebosglobe',
#  'official twitter of the miami southridge club',
#  'mayor of mizners big kahuna of grog grotto level boss at player friend of finnegan s vice president of the poor judgment crew',
#  'first greek twitter page for cimorelli promos news owned by proud fan iownaustinsdick eficimz louu we love you guys cimfam',
#  'it s ryan former cohost of get board pods unknown i recycle garbage tv lost vhs for your viewing pleasure',
#  'leading news source in the mobile and digital health community covering mhealth digitalhealth healthapps subscribe here http t co bssgljabmf',
#  'interfaith counselors and life coaches with a focus on north node astrology we are spiritual advisers and welcome all religious faiths into our fold',
#  'follow me for cool etsy craft',
#  'newlos nosecrts ultraslump zona music a motion ward',
#  'follow us to get the latest news about',
#  'teambelize gemini stapleton eastny ballwaslife',
#  'support west ham live in nz eat macarons support west ham if there was a d it would be silent proud husband father to a gorgeous girl may',
#  'latest news from philadelphia updates are frequent',
#  'yea i had ya man buying me mad snacks wuts good',
#  'certified er',
#  'real music for wales on fm dab online home of the big welsh wake up with niall ruth whats on nationradiolive news nationradionews',
#  'follower of jesus christ lover of life and people enfp starbucks partner',
#  'kitson flagship store on robertson boulevard is the favorite stop for many celebrities and the who s who in hollywood oh did we offend you sorryboutit',
#  'bringing pie back one slice at a time furry software hockey and often less than politically correct wit my liver may be fucked but my heart is honest',
#  'the princeton herald is the official newspaper for the city of princeton texas visit our website or call to advertise or subscribe',
#  'eat healthy foods to stay healthy',
#  'original content producers will earn from tsu https t co jksk av a when their content attracts views',
#  'indianapolis city and press',
#  'pr professional writer thinker fitness enthusiast football lover angostura rum fc barcelona',
#  'video production company filming in tennessee and texas to us we are capturing more than a video it s your story',
#  'i m is a czech adult model and pornographic actress with inch natural breasts currently livin in london you can follow me and retweet me every day luv u',
#  'the official shrewsbury town football club twitter account bringing you the latest news from the shrews salop telephone',
#  'daily update women blog',
#  'the johnstown tomahawks are a junior hockey organization and proud member of the north american hockey league',
#  'i m just another trying hard to fit right in',
#  'i d love to connect with you online amherst wi milwaukee wi dayton oh rudolph wi neenah wi',
#  'tira aro ace aspiring artist drawing animal pals telagram skype tiramiwsho carecru alt tatterdneckwear',
#  'taku fand m wh re markiplite skelet n clique manicpanda is my sister t many nightmares and n t enough dreams',
#  'e t snapchat juhnior',
#  'curating the best media feeds in st louis a city in http t co awasxinsof a community service media network supporting civic causes and local arts',
#  'glenoak junior just a young girl trying to make it out like everybody else',
#  'a private catholic college prep school for young men',
#  'male from west midlands england spain is quality gold chill on my computer and xbox of the time youtube munkychunky joeysalads ftw',
#  'blood makes you related loyalty makes you family',
#  'director of paid search',
#  'lel',
#  'i almost never tweet so when i do it has to be good right',
#  'intelligent funny narcissistic lazy ass introvert do the math jaguar',
#  'don t let anyone tell you that you can t do it love what you do until you don t love it anymore nothing s impossible chowan',
#  'motovlogger from london make sure you go check out my videos on youtube ashalizir on instagram',
#  'you miss of the shots you don t take wayne gretzsky michael scott',
#  'in bianca s heart mind and soul',
#  'cheerleader cat herder den mother',
#  'i m blessed',
#  'news analysis and perspective on epa regulations and the climate change policy debate',
#  'the union network is all about entertainment professionals coming together to work and promote collectively as a team',
#  'deepfin co owner writer humor sports are what you ll find here magic noles jaguars redsox unf dadlife vaping kappaalphaorder brother',
#  'jordandivero iaurensmith your like the only one on twitter whos funny of course',
#  'celebrating abundance with the th all ways apples festival on wednesday th october tweets sent by dig for devonport co ordinator tess wilmot',
#  'dj creative director visual artist social media coordinator influencer stylist youtuber bookroxyayala gmail com instagram officialroxyayala',
#  'shakespearean ucc alumni dominican esl teacher musician newark new jersey born raised kean spursnation',
#  'do something today that your future self will thank you for',
#  'the flock will fly again all hail dolan alla quackbar',
#  'i m here to tweet lego legends ssbm',
#  'fast and easy prescription savings right at your fingertips',
#  'tlu pre nursing cowboysnation till the day i die',
#  'i know i m mad because iv always been mad',
#  'earn bitcoin through our network http t co rya jmlz q we sell online advertising simple product great potential we use only bitcoin fully automated',
#  'african proudly nigerian fashi n m del agricultural scientist change seeker feminist basically a rockstar',
#  'the new hampshire and maine source for news in strafford rockingham and york counties',
#  'lotion producer songwriter lover fighter hated by some but a friend to many jlo t i chris brown teyana taylor jojo and a lot more to come god willing',
#  'president personal spaceflight advisors llc author and design engineer',
#  '',
#  'mathy theorycraft type for elemental shaman in wow usually grumpy and or cynical',
#  'god eater zero escape dragon age lover of terrible puns anders and elves ojicon and procrastinator extraordinaire da i at damixillia',
#  'we are dedicated to bring you the news of the digital world',
#  'swisha splitta',
#  'addicted to nail polish in love with stamping plates',
#  'phoenix city and press',
#  'single goth footfetish',
#  'writer beautiful but unlikely http t co v s yxqcha the mojo collector http t co dnchecxj z is that a good thing or a bad thing',
#  'god st my family boxing and muay thai your only as good as your word actions speak louder snapchat vwashington',
#  'page dedicated to martin freeman by his fans the freemartinis join us for the latest news and pics',
#  'oh i m a good old rebel now that s just what i am and as for this union nation i do not give a damn',
#  'littlenialler https t co j ihq akps',
#  'your source for the latest news on sailing',
#  'ganking guwop watahpark otf moodyworld',
#  'ddct',
#  'louis tomlinson niallofficial love ya man',
#  'life and writing coach proud parent socialist',
#  'herb gardening with a proven method grow your own herbs inside outdoors great food teas medicinal herbs',
#  'i m opinionated if you don t like it block me i don t cry over spilled whine',
#  'wan na save the world don t know how',
#  'sc charli paige',
#  'be happy',
#  'my old account annabellxox locked me out ffs',
#  'i am a feminist latina an immigrant an activist somewhat of a socialist a marxist i believe in fighting for others human civil rights united we are',
#  'god often speaks to me through christian dior gcb r i p',
#  'rip to my lovely angels lulu yamil montrico',
#  'always a chef by trade chef by nature now working as the la rose noire brand manager with la rousse foods',
#  '',
#  'cls student in ku',
#  'openrp lewd non mostly dom i m a male thylacoleo my awesome best friend mrs samusaran open gf betterackerman shapeshifter straight',
#  'yahoo answers environment alternative fuel vehicles conservation global warming green living',
#  'shameless pervert all of my nicholaslister tweets plus a bunch of extra nsfw perverted loonery',
#  'official twitter account for the ohs src bringing you the best news and updates follow us and our exec jacksonpye gagewood gracie grahamaidan src',
#  'quiero un amor bonito de esos que te dan mariposas en el estomago',
#  'the meatless grilling guide live bbq fresh',
#  'news and insight from the team at hallmark business connections hallmark s b b unit',
#  'major league producer produced by hunnidroundz all inquiries hit up hunnidmngt gmail com instagram hunnidroundz',
#  'law graduate aviation personality pilot in view posts on everthing about aviation industry analysis news photos and lots more follow also gats aero',
#  'littlenialler',
#  'acme body paint in jamaica plain ma is a friendly knowledgeable and quality body shop let us get you back on the road again',
#  'littlenialler',
#  'littlenialler',
#  'fuck it trapgangent you got ta know where i m from to get to know a nigga',
#  'https t co j ihq akps littlenialler',
#  'woman who despairs with ignorance and bigotry likes talking and apparently is quite good at it transteachersmatter',
#  'the moon s love child ig majinpeach',
#  'littlenialler',
#  'littlenialler https t co j ihq akps',
#  'i am known by many names you may know one of them i m going to marry higashiyama seika ds fc',
#  'fahima was born in the village of harlem nyc and is a producer at large for pacifica radio works as a consultant and is an adjunct university professor',
#  'christian in the true sense of the term retired entertainer devout hard center democrat and avid political junkie',
#  'traveling boots and dancing shoes',
#  'us based content writers we write good stuff',
#  'blogger reader and feminist from the uk probably listening to halsey or obsessing over twenty one pilots on tumblr',
#  'game designer gloomth prince obsessive eater of food wearer of clothes making adr ft threeonezero opinions are his own',
#  'former cabin crew llb hons sportslaw phd student married with boys luca mico writing st book wheelchair user',
#  'i came from nothing americus ga to carthage tx panola fillies philippians',
#  'lagos',
#  'till the end of the line',
#  'littlenialler https t co j ihq akps',
#  'sunsets and adventures',
#  'theoretische forschung der naturwissenschaften buchautor schwerpunkt astronomie physik medizin komponist vorwiegend romantische musik',
#  'she is clothed in strength and dignity laughs without fear of the future proverbs ughs class of uw madison freshman',
#  'proud wife of american hero combat wounded vet usmc major james frederick wilson supporter of human rights injustice step mom animal lover hiippy adjacent',
#  'when you re young you just run but you come back to what you need the mountains are my beach the snow my ocean',
#  'pessimistic diehard united fan rants a lot mufc united',
#  'rip bean the good and bad die carry on',
#  'hooper i dont descriminate all girls welcome',
#  'james bond doesn t have to put up with this kinda shit i love strifechaospain more than life hisprincess',
#  'here s what s currently playing on wzbc fm in boston',
#  'sun music internet radio flowing free and on demand the adult urban alternative featuring four music styles and buy what you hear listen now',
#  'ct',
#  'yahoo answers environment alternative fuel vehicles conservation global warming green living',
#  'web designer and front end developer digital media enthusiast and fitness fan love football travelling and my mac a good cup of tea coffee always helps',
#  'life is a little kitten please give hugs daily open dms mp ouverts sexual orientation is n',
#  'the nation s leading voice on underground alternative punk music and youth culture both in print and online since follow us for news music more',
#  'the only failure is failure to try',
#  'wwu seusayahh',
#  'artist co founder of tripmusicgroup creative director inquiries contact mike p or funkyd gmail com ig blacasso x tripmusicgroup',
#  'i believe if you keep god first then all things are possible',
#  'baby we could be enough',
#  'social media junkie love travel photography actor lake lover startup adviser',
#  'llsd',
#  'next rated music promoter for massive music video artist promotion web design contact info loyaltyloaded com',
#  'potty mouth blondie gamer wrestling fan of soldier and little monster a bit nerdy',
#  'herb gardening enthousiast shares simple yet very practical tips to help struggling herb gardeners achieve a beautiful healthy herb garden all year',
#  'asst professor chief marketing communications officer consultant artist',
#  'birmingham',
#  'ceo founder of bragg live foods life extension nutritionist author health crusader speaker and nutrition adviser to world leaders and hollywood stars',
#  'this is the backup page so y all follow me on this page plus instagram reddick reezy snapchat me d reezy http t co wzeghuecbm',
#  'live in milwaukee wi love sports and my small family ask me anything and i will likely give you an interesting response',
#  'passionate about equality feminism fairness labour member pro corbyn',
#  'music production dj https t co by ii ah',
#  'laid back cat allergic to dumb azz people goin off on jokers is my anger management go ahead test me i ll hit you with a mansitchoazzdown',
#  'yahoo answers environment alternative fuel vehicles conservation global warming green living',
#  'supply chain management news published daily scm supplychain procurement logistics',
#  'music inquires verses collabs bookings contact johnson isaiah gmail com late nights turnt early mornings coming soon http t co jnq epqjed',
#  'witnessing jesus preaching teaching saving healing',
#  'andrea giantsnation',
#  'tweets with latest jobs offers in detroit',
# ...
#  'my is in iraq iraqi armenian https t co k rxgfrwpl',
#  'disciple husband father son pastor author fb https t co vtyonb cz teamjesus kingdomcovenant hypergrace navyvet',
#  'currently a bun with no time for humanproblems',
#  'tweets inspiring fun unusual extraordinary thoughtful delicious relevant livereal livepositive craphappens persevere happinessexists',
#  'christ follower husband dad pastor love the local church and leadership toronto maple leaf fan don t judge me',
#  'rip carterrio johnson',
#  'my favs markiplier jack septic eye stevoptweets bubblebutt c markipliershero septicarmy meowipliersquad for dayyss x',
#  'phd student in political theory vice freelancer newfoundlander in exile i write about canada and stuff pic courtesy fogtownfemme',
#  'hi all i am based in hertford and very interested in working from home i help others achieve this too to learn more http t co h htrnyj',
#  'geek dad husband geopolitical photography coins cars financials foodie pro family pro military pro capitalism pro america',
#  'i am a job having dvr watcher mitsubishi driving burger lovin jordan buying wooooooo coolest daddy of the world have ever seen wooooooo elbow drop',
#  'covering the latest news in all the areas of science tell us what you think on weekly scientific inventions and discoveries',
#  'from mechanical to mechatronic engineer binge watcher in the meantime tech news addicted pgp https t co tliufa',
#  'hi let s be friends',
#  '',
#  'hello i am a time lord aged who is proud to be working class i had a year old dog called muttley who died rd june rip refugeeswelcome',
#  'primeonly online surplus electronics power adapters computer parts lasers optics industrial controls some beekeeping supplies new us seller',
#  'hustlerneur frg foreign',
#  'wsu',
#  'king eric cantona times ysb',
#  'sports writer capital baltimore sun media group stadium journey ny jets yankees terps marist columbia md via nj w wife daughter border terrier',
#  'paradigm hifter follow yourbeautybliss order the iconoclast https t co ybodpzsuja',
#  'link news about dominican',
#  'highly plusher deals',
#  'dah vy multimedia artist pianist https t co wbwnqj iwt',
#  'i want you to ask yourself what you can accomplish given new and limitless possibilities existing beyond the scope of this meagre reality',
#  'excuse me i got in a spelling test once',
#  'i m a dreamer loving life goodness of people i d like live on countryside encircled by my pets i write poems i ll read its only who ll be in my life',
#  'can t wait to meet my lil princess feb th',
#  'gamer who won t take bullshit from anyone',
#  'reptile lovers owners custom and handmade decor for your reptiles check out our etsy shop message us is you have any questions or to order',
#  'assassin s creed news from reddit',
#  'get free bitcoins at http t co bn sdbjb btc faucets',
#  'hull bands n eminem',
#  'my resume http t co qq olv qpl',
#  'charles a francis meditation teacher huffpost blogger author of mindfulness meditation made simple your guide to finding true inner peace quote love',
#  'gay ny costa rican guatemalan',
#  'theopaphitis sbswinners sbsmonthlywinner ranked th in uk reviews online pmlunch fblikehour host as seen on madeinleeds',
#  'loveahappyending lifestyle magazine contributors from the uk us and canada lahe',
#  'sina costume artist singer chief editor of cohakumagazin german ambassador of scg',
#  'deb n hair salon award winning hairdressing loreal colour trophy regional final winner stylist rikki theodosi instagram rikkitheodosi',
#  'sorry about the lame username',
#  'hi i m sindy i love ulzzang gyaru fashion makeup circle contacts and coffee',
#  'updates and news on upcoming events from the confboardofcda we live tweet during our events too',
#  'take me back to the basics and the simple life',
#  'the johnstown tomahawks are a junior hockey organization and proud member of the north american hockey league',
#  'a product of grace in search of everyday graces a sometimes sassy but mostly southern woman who loves jesus life laughter and lattes extj',
#  'lancashire s more music station fm in chorley fm in preston south ribble fm in blackburn darwen hyndburn snapchat thebeeradio',
#  'alt writing twitter for internet superstar lord daddy dont follow if under plz anything too spicy or personal for my main twitter will live here',
#  'ilona horvath business woman musician and artist of all kinds let the beauty melt your soul',
#  'maried to tanya daughters shaunie chantel and shanice also have two grandsons rylie and kayne',
#  'rough tasteless',
#  'youtuber gamer boyfriend got the life',
#  'been her still her rip dad',
#  'no',
#  'i love to fuck a lot am straight and lesbian both boys and girls are welcomed follow and dm me for contact',
#  'director of global brand business development mullenlowegroup former yacht queen intersailclub',
#  'alex cena is a financial analyst and equity research professional for institutional investors avid outdoorsman and photographer',
#  'i tweet about about dumb stuff including but not limited to superheroes tokusatsu anime the walking dead robits video games total loser',
#  'i m president founder propheta communications inc a manhattan based public relations agency my team and i bridge the gap between perception reality',
#  'basically the cure to the world s problems is erectile dysfunction',
#  'trying to refigure things out for myself fisheries marine ucdbc',
#  'the official account for st pancras international a destination station transport dining shopping arts culture',
#  'teamstupidaf teamskinnyaf teamdrinkspiritonsundaytogetspiritual teamgetdrunktweetwakeupdelete teamdontcare teamsupport teammafisi teamhigh teamteam',
#  'in loving memory of luke skywalker he aint dead yet just missing hw',
#  'crowdsourcing innovation the finnd connects fed govt industry academia to solve hard problems overcome obstacles in the contracting process',
#  'here s to the crazy ones the misfits the rebels the troublemakers',
#  'a member of the haunted events uk team global cpfp manager for ppg pmc',
#  'lover fighter networker i am all things to all men',
#  'bang thy head rock thy beard circle thy pit hoist thy ale and rejoice i also drink beer and do vocals in allfatheruk',
#  'how does moses make his tea hebrews it',
#  'personal assistant website admin of wildoutcrewgh crazy love bae s favorite',
#  'rep in summer for club in zante live for the nights you can t remember but will never forget all views are my own',
#  'stay focused extra sparkley chs',
#  'with five hospitals florida hospital is the largest hospital system serving volusia and flagler county residents',
#  'alex g rard i draw badass or cute things get in touch contact icybomb be',
#  'thought i was an atheist until i realized i m a god',
#  'professional footballer for qprfc nikeuk athlete co founder of excelracing co founder of ca football and of course a proud dad',
#  'o o holland enterprises freak harvick on periscope dad of nascar harvicknation thecup thewin cowboys trojans bama dodgers thankatruck',
#  'staff columnist for the toronto star i write saturdays in news and mon wed on the five neat guys opinion pages email hmallick thestar ca',
#  'football enthusiast mufc redarmy bastian schweinsteiger manchesterisred',
#  'growth hacker nerd online marketing manager at vionelfilm vionel also a foodie gym junkie and notorious traveler blogs at http t co omol oqmj',
#  'blackfish born on the prairies but my heart is in the ocean tilikum kiska freelolita tweet taiji seashepherd opgrindini',
#  'peace life love freedom music r i p ashley mccrae r i p kk jetlife snobmob tde tgod highpointe allcaps instagram ms kushington',
#  'chair of peopleslobbyusa vicar firsttrinitychi tweeting progressive politics global political economy snarky theology miley cyrus',
#  'i am who i say i am and i do what i say i m gone do',
#  'professor of philosophy at city university of new york',
#  'when i die i wan na go to hell cause i m a piece of shit it ain t hard to fucking tell',
#  'deltek s govwin solutions are designed specifically for gov t contractors aiming to grow their business and win more contracts',
#  'yearsold',
#  'perhaps insanity is to see life as it is rather than as it should be cervantes',
#  'humanely reducing the cat population via tnr serving as a model and mentor for other communities with the vision of ending the euthanasia of cats in shelters',
#  'regelmatig nieuwe tips foto s video s inspirerende quotes eigenaar van cadeaus nl tshirt me nl',
#  'twitter page for the missional communities at river city church',
#  'hi everyone machinima partnered youtube http t co fx frbwkq subs twitch dolphin dive pro cambridgeshire',
#  'defender of secular spaces feminist sometimes a writer sometimes a reader',
#  'i m so glad that i live in a world where there are octobers',
#  'ibm systems is middleware hardware built for today s digital economy follows ibm social computing guidelines maintained by catnickery skatzenmaier',
#  'treat yourself like harry styles would treat you',
#  'puertorican love to dance and play guitar music means a lot to me',
#  'chs senior thespian',
#  'the new and improved apple ibear now in hd',
#  'never work out alone',
#  'arsenal theozilan manuel lanzini marc bartra adam lallana enthusiast',
#  'i sing in a band nascum engadget reporter gingercaster gingercast cat lord',
#  'strafford high school located in strafford mo',
#  'you re like an imperfect poem or an incomplete piece of art flawed but still flawless access to nj lj',
#  'sharkwave is mine',
#  'alphacrew',
#  'the official twitter account of purdue university',
#  'sahmama of just trying to figure out where to go from here slimming world stone loser weightloss pblogger with a dash of autism thrown in for fun',
#  'technology news on my blog at http t co kr fg e u',
#  'i suffer from too much pep i needed a pep outlet loves genre fiction tv analysis liberal politics wine contributor at https t co laglmkjkkm',
#  'if god be for me who can be against me madridista',
#  'this account is trying to keep track of everything that happens in the popular subreddits on reddit this is a bit and simply posts what others post on reddit',
#  'luxury goods store featuring watches leather silver and jewellery and gun rifle makers bruton street w j qx',
#  'a happy wife mom of blogger functioning on jesus and coffee',
#  'i am not a duck',
#  'inspiritangelbabyarmyboicestarlight up tionlovelyzstan',
#  'structural biology and bioinformatics cephalopods and felids comics and butts team gay and team poly',
#  'god bless',
#  'pdx portland state university student at recording connection',
#  'trix are for kids',
#  'marketing for http t co il mj xzsq work for a globally recognized company deltek pet fish a passion for flying boating an awesome life',
#  'wsra is an association of recycling professionals that works to expand the knowledge enhance the skills and advance the careers of our members',
#  'bitter iris west stan iwds',
#  'growing marginal crops on poor land',
#  'you have a little danger in your eye i wan na know what you plan to do with it maronitheboss calls me babes maturecontent rp reckless gotham',
#  'entertainer enetepreneur event consultant super model sanguine adventerous professional dancer creative',
#  'vi vi s s i s r call me maybe my two dad queria rica https t co pygqy sfx nat bea vic',
#  'struggles build you not break you',
#  'god love yoga health luxury washingtonian in chicago hoya bison trying to balance my lawyer half with my yogini half',
#  'i m kind of a big deal',
#  'i am simple my running chics line is simple and i like life to be simple after all life is a race be comfortable',
#  'http t co vb s yj e',
#  'i m basically just phan trash and i tweet about random shit k bye',
#  'a friendly and exciting pop music forum to discuss pop music and culture join today and get access to free downloads and more',
#  '',
#  'wife to colin mama to daniel kyle joshua reg blogger amateur photographer teaching assistant reader teaching student painter',
#  'tweets relating to the ge general election',
#  'runner cyclist reader of books lover of animals beer connoisseur vegan',
#  'demon swordsman makaalbarn and mrcoolguysoul are everything to me i used to drown in sadness now i ll look towards tomorrow sserp multirp',
#  'the lightskin princess mixed chick fifteen proving them wrong ashtin cade foulger',
#  'entrepreneur networkmarketing professional twitter instagram marketing coach beginners guide to twitter recruiting http t co olk yk zc',
#  'designer web professional internet fangirl netflix addict',
#  'otrapink my grades are c a c a caca disgusting',
#  'dundee home away dtid',
#  'mean girl',
#  'probably somewhere with jennaaucoin stfx',
#  'play call of duty for odinesports lans nerve hankzy is bae',
#  'ignatius l donnelly associate professor of old weird american secret canadian gilded age digital geek gaming big alternate and two fisted history',
#  'i sing for my supper',
#  'yeah that s sorta jazzy red sox patriots bruins terps',
#  'top gun elite u south lake',
#  'win or learn but never lose',
#  'white girl phenomenon under the guide of thephenomenalee youtube vlogger in training super smash brothers addict college senior',
#  'homemade cake jars est june sierrassweetlayers ssu',
#  'specialising in digital pr affiliate marketing brand collaborations follow us on instagram http t co ldykjrnwvs',
#  'michael and janet jackson have inspired so many people with their music and dance and michael s efforts to to help children dont ever forget michael jackson',
#  'lover of life lover of christ',
#  'i do graphics mostly when im bored and when im not playing or watching streamerino yo scandinavian',
#  'embarque no expresso de hogwarts com a gente desde',
#  'scorpio season is among us shadesofshe',
#  'destiny the game news from reddit',
#  'technology news on my blog at http t co kr fg e u',
#  'years young montreal pieces john abbott college',
#  'liltunechi malekrose izzoland aubreerose panama maxb gunzworld lilly lebron ava',
#  'full time dreamer vibe master',
#  'the best things in life are unseen that s why we close our eyes when we kiss laugh and dream',
#  'analyzing dreams for years use psychoanalytic techniques jung freud etc dreams on alcoholism addiction ptsd and recovery from these issues',
#  'viajes y traves as de aventura a medida en bolivia expediciones x amplia experiencia en manejo off road en la amazon a y el altiplano dakar overland',
#  'find local hookups for casual sex or have a discreet affair',
#  'badlandsgrl shypunks ur my chocolate donut',
#  'colors comics',
#  'donorhut makes fundraising easy and best of all it s free safely and securely accept donations online directly into your bank account',
#  'award winning producing theatre in belfast this month conor mcpherson s nightalive oct',
#  'meh',
#  'the northwelland business improvement area is home to a thriving diverse blend of retailers restaurants services in canada s vibrant rose city',
#  'rt means i love you my two favorite things are commitment and changing myself expert fuck the constitution i can say that because of the constitution',
#  '',
#  'hard rock band from the gulf coast usa new adrift e p out soon',
#  'a os rock erreap la felicidad es una carta de la baraja itsirenneg instagram sergiiip snap sergiiip',
#  'offering artists and audiences unprecedented opportunities for artistic exploration collaboration big ears returns march april',
#  'i m a cpa and business owner who writes every day on small business public policy for the washington post and weekly for forbes inc huffpo entrepreneur',
#  'some are born to sweet delight some are born to endless night herehavemyheart s little lamb',
#  'youngstown warren urban radio station',
#  'intermountain region sports i comment on sociopolitical issues but dislike the major parties veteran advocate for reform of the vamc utpol natsec',
#  'of my body is made of video games',
#  'tune in to theboxshowng sat pm rainbow fm lag wed pm sapientia fm onitsha fridays caritas fm enugu pm bca radio abia pm ksmc kaduna pm',
#  'block la familia wash hts i ll help you get your son out of p s get him a maury flow from the maury show',
#  'pizza',
#  ...]

# %% [markdown]
# Şu ana kadar yaptıklarımız şu şekildedir: Data'nın içerisindeki gereksiz karakterleri ortadan kaldırdık. Gereksiz karakterler ?, ! gibi ifadelerdir. Sonrasında tüm harfleri küçük harfe çevirdik. Ve sonra cümleleri parçalayıp, kelimeleri elde ettik. Kelimeleri elde ettikten sonra, her bir kelimenin kökünü bulduk. Sonrada bulduğumuz bu kökleri tekrar cümle haline getirerek birleştirdik.

# %% [markdown]
# ## Bag of Words

# %% [markdown]
# <br><br>
# <img src="n1.png" style="width:900px;height:300px"/>
#
# <br>
# <img src="n2.png" align="left" style="width:500px;height:200px"/>
#
# <br><br>
# Yukarıda sağ taraftaki görselin yapısı bu şekildedir.

# %% [markdown]
# Yukarıdaki görsel üzerinden Bag of Words'ü anlatayım. 3 adet cümle bulunmakta. Cümle içerisindeki her bir kelime bir feature olur. İlk cümlede "merhaba", "ben", "geldim" kelimelerei var ve bu kelimeler birer feature olur. Sonrasında 2.cümlede "merhaba" kelimesi var ve bu kelime, 1.cümledede vardı ve feature yapılmıştı dolayısıyla tekrar aynı kelime farklı feature olarak yazılmaz. Diğer kelimeler feature olarak yazılır. 3.cümle içinde aynı işlem yapılır.
#
# Sonrasında 1.cümlede bulunan kelimelerin olduğu feature altına 1 yazılır. 1.cümlede olmayan kelimelerin feature'lerine 0 yazılır. Diğer cümleler içinde aynı işlemler gerçekleştirilir.
#
# Böylece bag of words işlemi gerçekleştirilmiştir.
#
# Şimdi sklearn kütüphanesi ile bag of words metodunu yazalım.

# %%
from sklearn.feature_extraction.text import CountVectorizer #bag of words oluşturmak için kullanılan metottur.

max_features = 500

count_vectorizer = CountVectorizer(max_features = max_features, stop_words = "english")

sparce_matrix = count_vectorizer.fit_transform(description_list).toarray()

print("en sik kullanilan {} kelimeler: {}".format(max_features,count_vectorizer.get_feature_names()))
# Out:
# en sik kullanilan 500 kelimeler: ['account', 'activist', 'actor', 'addict', 'advocate', 'alum', 'amazing', 'america', 'american', 'animal', 'animals', 'anime', 'app', 'area', 'art', 'artist', 'arts', 'ask', 'aspiring', 'ass', 'author', 'award', 'away', 'awesome', 'baby', 'bad', 'band', 'based', 'basketball', 'beautiful', 'beauty', 'beer', 'believe', 'best', 'better', 'big', 'bio', 'bit', 'bitch', 'black', 'blog', 'blogger', 'book', 'booking', 'bookings', 'books', 'born', 'bot', 'boy', 'boys', 'breaking', 'building', 'business', 'care', 'cat', 'cats', 'ceo', 'certified', 'change', 'channel', 'check', 'chicago', 'child', 'children', 'christ', 'christian', 'city', 'class', 'club', 'coach', 'coffee', 'college', 'com', 'come', 'coming', 'community', 'company', 'conservative', 'consultant', 'contact', 'content', 'continuous', 'cool', 'country', 'county', 'crazy', 'create', 'creative', 'creator', 'culture', 'currently', 'dad', 'daily', 'dance', 'data', 'day', 'days', 'deals', 'dedicated', 'design', 'designer', 'developer', 'development', 'die', 'digital', 'direction', 'director', 'dj', 'dm', 'does', 'doesn', 'dog', 'dogs', 'doing', 'don', 'dont', 'dream', 'dreamer', 'dreams', 'eat', 'editor', 'education', 'el', 'email', 'en', 'end', 'endorsements', 'engineer', 'english', 'enjoy', 'entertainment', 'enthusiast', 'entrepreneur', 'estate', 'events', 'everyday', 'ex', 'experience', 'expert', 'facebook', 'family', 'fan', 'fanatic', 'fans', 'fantasy', 'fashion', 'father', 'favorite', 'fc', 'feed', 'feel', 'feminist', 'film', 'financial', 'finding', 'fitness', 'follow', 'followed', 'food', 'football', 'forever', 'founder', 'free', 'freelance', 'friend', 'friends', 'fuck', 'fun', 'future', 'game', 'gamer', 'games', 'gaming', 'gay', 'geek', 'general', 'girl', 'girls', 'global', 'gmail', 'god', 'going', 'gon', 'good', 'google', 'got', 'graduate', 'graphic', 'great', 'group', 'guy', 'hair', 'happiness', 'happy', 'hard', 'harry', 'hate', 'head', 'health', 'heart', 'hell', 'hello', 'help', 'helping', 'hey', 'hi', 'high', 'hip', 'history', 'hockey', 'home', 'hop', 'hope', 'host', 'house', 'http', 'https', 'huge', 'human', 'husband', 'ig', 'im', 'improve', 'independent', 'industry', 'info', 'information', 'inspirational', 'insta', 'instagram', 'interested', 'international', 'internet', 'jesus', 'job', 'jobs', 'join', 'journalist', 'junkie', 'just', 'justin', 'kids', 'kind', 'king', 'know', 'la', 'lady', 'latest', 'laugh', 'law', 'leader', 'leading', 'league', 'learn', 'learning', 'left', 'let', 'life', 'lifestyle', 'light', 'like', 'likes', 'link', 'little', 'live', 'living', 'll', 'local', 'london', 'long', 'look', 'looking', 'lost', 'lot', 'louis', 'love', 'lover', 'loves', 'loving', 'magazine', 'major', 'make', 'makes', 'making', 'man', 'management', 'manager', 'map', 'marketing', 'married', 'master', 'media', 'meet', 'member', 'mind', 'mobile', 'model', 'mom', 'money', 'mother', 'movies', 'mum', 'music', 'musician', 'na', 'national', 'nature', 'need', 'nerd', 'network', 'new', 'news', 'night', 'non', 'north', 'nsfw', 'obsessed', 'official', 'oh', 'old', 'online', 'open', 'opinions', 'owner', 'page', 'partner', 'passion', 'passionate', 'peace', 'people', 'perfect', 'person', 'personal', 'photographer', 'photography', 'pics', 'pizza', 'place', 'places', 'play', 'player', 'playing', 'pm', 'podcast', 'politics', 'pop', 'positive', 'post', 'power', 'pr', 'pretty', 'price', 'pro', 'probably', 'producer', 'professional', 'promoting', 'proud', 'provide', 'providing', 'public', 'quality', 'que', 'queen', 'radio', 'random', 'read', 'reader', 'reading', 'real', 'really', 'red', 'reporter', 'research', 'retired', 'retweets', 'right', 'rights', 'rip', 'rock', 'rp', 'rt', 'run', 'sales', 'say', 'sc', 'school', 'science', 'seattle', 'secret', 'self', 'senior', 'series', 'service', 'services', 'share', 'shit', 'shop', 'simple', 'singer', 'single', 'site', 'small', 'smile', 'snapchat', 'social', 'software', 'son', 'songwriter', 'sos', 'soul', 'source', 'south',  ...

# %% [markdown]
# Çıktıda en sık kullanılan 500 kelimeyi görmekteyiz.
#
# max_features = 500 ifadesi ile yapılan şudur: toplam 16224 tane cümle var. Bunlarda ortalama 32000 tane farklı kelime var diyelim. 32000 tane kelimenin içerisinden maksimum kullanılan 500 tanesini seçtik. Böyle yapıcaz çünkü diğer türlü algoritma çok yavaşlıyor.
#
# stop_words = "english" parametresi ile CountVectorizer metodu uygulanırken gereksiz kelimeler cümlenin içerisinden çıkarılır.
#
# Hatırlarsanız tüm kelimeleri küçük harfe dönüştürmüştük. Burada aynı işlemi lowercase parametresi ile de yapabiliriz. Birde re.sub metodu ile ".", ",", "!" gibi gereksiz parametreleri kaldırmıştık. Aynı işlemi burada token_pattern parametresiylede yapabiliriz. Fakat burada kullanmayacağız çünkü yukarıdaki kod bloğunun öncesindeki bloklarda tüm bu işlemleri yapmıştık.
#
# Literatürde 1 ve 0 değerlerinden oluşan matrix'e sparce matrix denir.

# %% [markdown]
# En sık kullanılan 500 kelimeye değilde, en sık kullanılan tüm kelimelere bakalım:

# %%
"""
from sklearn.feature_extraction.text import CountVectorizer #bag of words oluşturmak için kullanılan metottur.

count_vectorizer = CountVectorizer(stop_words = "english")

sparce_matrix = count_vectorizer.fit_transform(description_list).toarray()

print("en sik kullanilan kelimeler: {}".format(count_vectorizer.get_feature_names()))
"""
# Out:
# '\nfrom sklearn.feature_extraction.text import CountVectorizer #bag of words oluşturmak için kullanılan metottur.\n\ncount_vectorizer = CountVectorizer(stop_words = "english")\n\nsparce_matrix = count_vectorizer.fit_transform(description_list).toarray()\n\nprint("en sik kullanilan kelimeler: {}".format(count_vectorizer.get_feature_names()))\n'

# %% [markdown]
# 29144 tane  kelime elde edilmiştir.

# %% [markdown]
# feature'lerin olduğu data sparce_matrix'te tutulmakta. Dolayısıyla x=sparce_matrix.

# %%
y = data.iloc[:,0].values  #y=gender
x=sparce_matrix

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=42)

# %% [markdown]
# naive bayes algoritması ile model oluşturalım.

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
#prediction

y_pred = nb.predict(x_test)

print("accuracy: ",nb.score(y_pred.reshape(-1,1),y_test))
# Out:
# accuracy:  0.4232902033271719

# %% [markdown]
# Çok düşük bir doğruluk değeri elde ettik. max_features=500 ifadesinde 500 değerini artırarak doğruluk oranını da artırabiliriz.
